# %% [markdown]
# # Text to Speech Conversion Using gTTS

# %%
pip install gtts
# Out:
# ...
#
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech=gTTS('''Internship Opportunity : Java, Python, Data Science, Full stack Developer, and Training

Are you passionate about software Development and eager to gain hands-on-experience in cutting edge technology? Join our team as an intern and tech your skills to the next level ''')
text_to_speech.save('text_to_speech_gtts.wav')
sound_file='text_to_speech_gtts.wav'
Audio(sound_file,autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
intro=gTTS('''Hello my dear friends i am AMit singh''')
intro.save('intro_gtts.wav')
sound_file='intro_gtts.wav'
Audio(sound_file,autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Text to speech conversion using pyttsx3
# changing the gender using pyttsx3

# %%
pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3
from IPython.display import Audio

# %%
text=gTTS('''Internship Opportunity : Java, Python, Data Science, Full stack Developer, and Training

Are you passionate about software Development and eager to gain hands-on-experience in cutting edge technology? Join our team as an intern and tech your skills to the next level ''')
audio=pyttsx3.init()
audio.setProperty('rate',150)
audio.setProperty('volume',0.8)
# change the voice
voice=audio.getProperty('voices')

# 0 for male or 1 for female
#audio.setProperty('voice',voice[0].id)
audio.setProperty('voice',voice[1].id)

#convert text to speech
audio.say(text)

#save audio file
#audio.save_to_file(text,'text_male_voice.mp3')
audio.save_to_file(text,'text_female_voice.mp3')

audio.runAndWait()

# %%
text2=gTTS('''Hello my dear friends i am amit singh''')
audio=pyttsx3.init()
audio.setProperty('rate',150)
audio.setProperty('volume',0.8)
# change the voice
voice=audio.getProperty('voices')

# 0 for male or 1 for female
audio.setProperty('voice',voice[0].id)
#audio.setProperty('voice',voice[1].id)

#convert text to speech
audio.say(text)

#save audio file
audio.save_to_file(text,'text_male_voice.mp3')
#audio.save_to_file(text,'text_female_voice.mp3')

audio.runAndWait()
